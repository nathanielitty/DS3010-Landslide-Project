# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./Complete-data.csv')
df.head()
# Out:
#    Landslide  Aspect  Curvature  Earthquake  Elevation  Flow  Lithology  NDVI  \
# 0          0       3          3           2          2     2          1     4
# 1          0       1          5           2          3     1          1     4
# 2          0       3          4           3          2     2          4     3
# 3          0       1          3           3          3     5          1     2
# 4          0       5          4           2          1     4          1     2
#
#    NDWI  Plan  Precipitation  Profile  Slope
# 0     2     2              3        3      2
# 1     2     5              5        2      2
# 2     2     4              5        2      2
# 3     4     3              5        3      3
# 4     4     3              3        1      4

# %%
df.describe()
# Out:
#          Landslide       Aspect    Curvature   Earthquake    Elevation  \
# count  1212.000000  1212.000000  1212.000000  1212.000000  1212.000000
# mean      0.500000     2.962046     2.977723     2.102310     2.436469
# std       0.500206     1.147378     1.099658     0.669812     1.242686
# min       0.000000     1.000000     1.000000     1.000000     1.000000
# 25%       0.000000     2.000000     2.000000     2.000000     1.000000
# 50%       0.500000     3.000000     3.000000     2.000000     2.000000
# 75%       1.000000     4.000000     4.000000     3.000000     3.000000
# max       1.000000     5.000000     5.000000     3.000000     5.000000
#
#               Flow    Lithology         NDVI         NDWI         Plan  \
# count  1212.000000  1212.000000  1212.000000  1212.000000  1212.000000
# mean      2.338284     1.948845     3.042904     2.773927     3.059406
# std       1.112686     1.424345     1.239246     1.299830     1.057287
# ...

# %%
df.isnull().sum()
# Out:
# Landslide        0
# Aspect           0
# Curvature        0
# Earthquake       0
# Elevation        0
# Flow             0
# Lithology        0
# NDVI             0
# NDWI             0
# Plan             0
# Precipitation    0
# Profile          0
# Slope            0
# dtype: int64

# %% [markdown]
# This means that the dataset does not have any missing values so data cleaning is not necessary.

# %%
landslide_count = df['Landslide'].value_counts()
sns.set(style="darkgrid")
sns.barplot(x=landslide_count.index, y=landslide_count.values, alpha=0.9, palette="viridis")
plt.title('Frequency Distribution of Landslides')
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Landslide', fontsize=12)
plt.show()

# %% [markdown]
# The dataset is balanced! 600 occurrences for each class, even class distribution.

# %%
plt.figure(figsize=(13, 13))
sns.heatmap(df.corr(), annot=True)

plt.show()

# %% [markdown]
# From the heatmap, we see that precipitation has the highest correlation with landslides.

# %%
# %matplotlib inline

# %%
for feature in df.columns:
    plt.figure(figsize=(8, 6))
    sns.histplot(df[feature], kde=True)
    plt.title(f'Distribution of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')
    plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df)
plt.xticks(rotation=45)
plt.show()

# %%
sns.pairplot(df)
plt.show()
# Out:
# C:\Users\Nath\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

X = df.drop(columns=['Landslide'])
y = df['Landslide']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

rf_model = RandomForestClassifier()
rf_model.fit(X_train, y_train)

plt.figure(figsize=(10, 6))
sns.barplot(x=rf_model.feature_importances_, y=X_train.columns)
plt.title('Feature Importance')
plt.xlabel('Importance Score')
plt.ylabel('Features')
plt.show()
